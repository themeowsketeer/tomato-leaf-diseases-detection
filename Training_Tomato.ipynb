# %% [markdown]
# <a href="https://colab.research.google.com/github/themeowsketeer/tomato-leaf-diseases-detection/blob/main/Training_Tomato.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-253-g63555c8 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 26.3/166.8 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q ../yolov5/sample_16_12_2023 -d ../sample_16_12_2023

# %%
import shutil

shutil.rmtree('/content/sample_14_11_2023')

# %%
# !zip -r /content/detectFinal_20_12_2023 /content/yolov5/runs/detect/exp
# Out:
#   adding: content/yolov5/runs/detect/exp/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp/IMG_6734.jpg (deflated 0%)
#   adding: content/yolov5/runs/detect/exp/IMG_6932.jpg (deflated 0%)
#   adding: content/yolov5/runs/detect/exp/LB_ (247).jpg (deflated 3%)
#   adding: content/yolov5/runs/detect/exp/Late Blight JPEG_original_IMG_6878.jpg_59683735-5f13-4a07-98e9-c737f4b7d6b7.jpg (deflated 4%)
#   adding: content/yolov5/runs/detect/exp/IMG_6808.jpg (deflated 0%)
#   adding: content/yolov5/runs/detect/exp/IMG_7067.jpg (deflated 0%)
#   adding: content/yolov5/runs/detect/exp/Late Blight JPEG_original_IMG_6864.jpg_dbda3f19-2d93-40e6-baad-5121755d33e0.jpg (deflated 4%)
#   adding: content/yolov5/runs/detect/exp/Late Blight JPEG_original_IMG_6876.jpg_5a899b77-ee22-4818-959e-36536c3a63d7.jpg (deflated 4%)
#   adding: content/yolov5/runs/detect/exp/IMG_7052.jpg (deflated 0%)
#   adding: content/yolov5/runs/detect/exp/IMG_6962.jpg (deflated 0%)
# ...

# %%
# !zip -r /content/weightFinal_20_12_2023 /content/yolov5/runs/train/exp2
# Out:
#   adding: content/yolov5/runs/train/exp2/ (stored 0%)
#   adding: content/yolov5/runs/train/exp2/opt.yaml (deflated 49%)
#   adding: content/yolov5/runs/train/exp2/val_batch1_labels.jpg (deflated 7%)
#   adding: content/yolov5/runs/train/exp2/R_curve.png (deflated 7%)
#   adding: content/yolov5/runs/train/exp2/PR_curve.png (deflated 16%)
#   adding: content/yolov5/runs/train/exp2/labels_correlogram.jpg (deflated 39%)
#   adding: content/yolov5/runs/train/exp2/val_batch2_pred.jpg (deflated 6%)
#   adding: content/yolov5/runs/train/exp2/P_curve.png (deflated 10%)
#   adding: content/yolov5/runs/train/exp2/train_batch2.jpg (deflated 3%)
#   adding: content/yolov5/runs/train/exp2/val_batch2_labels.jpg (deflated 6%)
#   adding: content/yolov5/runs/train/exp2/events.out.tfevents.1703083865.0f3e92fb68b9.2003.0 (deflated 34%)
#   adding: content/yolov5/runs/train/exp2/train_batch0.jpg (deflated 3%)
#   adding: content/yolov5/runs/train/exp2/F1_curve.png (deflated 7%)
# ...

# %%
# !unzip -q ../weights -d ../

# %%
# !python val.py --weights best_Hieu.pt --data path.yaml --img 640 --half

# %%
# !python detect.py --weights best.pt --img 640 --conf 0.2 --source ../sample_16_12_2023/images/test/
# Out:
# detect: weights=['best.pt'], source=../sample_16_12_2023/images/test/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-253-g63555c8 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20869098 parameters, 0 gradients, 47.9 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/370 /content/sample_16_12_2023/images/test/00b7e89a-e129-4576-b51f-48923888bff9___GCREC_Bact-Sp-6202_JPG.rf.ef2b2240b73ff512deedc34584bc0ee5.jpg: 640x640 1 bacterial_spot, 7.2ms
# ...

# %%
# !python train.py --img 640 --batch 32 --epochs 300 --data path.yaml --weights bestDemo.pt --cache disk --save-period 50
# Out:
# 2023-12-20 14:51:03.386713: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-20 14:51:03.386761: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-20 14:51:03.387990: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
torch.cuda.empty_cache()

# %%
# !python train.py --resume epoch400demo.pt
# Out:
# 2023-12-18 08:13:22.914545: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-18 08:13:22.914599: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-18 08:13:22.916129: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
